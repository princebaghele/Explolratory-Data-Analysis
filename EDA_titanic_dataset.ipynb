# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat
import seaborn as sns
# Import necessary libraries for data manipulation, numerical operations, and plotting.

# %%
print(len(data))
# Print the total number of rows (entries) in the DataFrame.

# %%
data = sns.load_dataset('titanic')
print(data)
# Load the Titanic dataset from Seaborn and print the first few rows.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.info()
# Display a concise summary of the DataFrame, including data types and non-null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.describe()
# Generate descriptive statistics of the numerical columns in the DataFrame.
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.head()
# Display the first 5 rows of the DataFrame.
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.tail()
# Display the last 5 rows of the DataFrame.
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
data.columns
# Display the names of all columns in the DataFrame.
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
print(data.dtypes)
# Print the data types of each column in the DataFrame.
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
data['pclass'].value_counts()
# Count the occurrences of each unique value in the 'pclass' column.
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
np.mean(data['pclass']==1)
# Calculate the proportion of passengers in 'pclass' 1.
# Out:
# np.float64(0.24242424242424243)

# %%
data[['pclass', "survived"]].groupby(["pclass"]).mean()
# Calculate the survival rate for each passenger class.
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
print(len(data))
# Out:
# 891

# %%
#count prompt
sns.catplot( x ='sex', hue='survived', kind='count', data=data)
# Create a count plot to visualize the survival count based on sex.

# %%
sns.catplot( x='sex', y='survived', hue='sex',data=data)
# Create a categorical plot to show survival rates by sex.

# %%
sns.catplot( x='sex', y='survived', hue='sex',kind='bar', data=data)
# Create a bar plot to compare survival rates between male and female passengers.

# %%
sns.catplot(x='sex', y='survived', hue='pclass', kind='violin', data=data)
# Create a violin plot to show the distribution of survival by sex and passenger class.

# %%
sns.catplot( x='sex', hue='pclass',kind='count', data=data)
# Create a count plot to show the distribution of passenger classes by sex.

# %%
data[data['sex']=='male'].groupby('pclass')['survived'].sum()
# Calculate the total number of male survivors in each passenger class.
# Out:
# pclass
# 1    45
# 2    17
# 3    47
# Name: survived, dtype: int64

# %%
data[data['sex']=='female'].groupby('pclass')['survived'].sum()
# Calculate the total number of female survivors in each passenger class.
# Out:
# pclass
# 1    91
# 2    70
# 3    72
# Name: survived, dtype: int64

# %%
sns.catplot(
    x="pclass",
    y="survived",
    hue="sex",
    kind="bar",
    data=data
)
# Create a bar plot to compare survival rates across passenger classes, separated by sex.

# %%
data[
   ( data['sex']=='female') & (data['survived']==0)].groupby('pclass')['survived'].count()
# Count the number of non-surviving female passengers in each class.
# Out:
# pclass
# 1     3
# 2     6
# 3    72
# Name: survived, dtype: int64

# %%
data[
   ( data['sex']=='male') & (data['survived']==0)].groupby('pclass')['survived'].count()
# Count the number of non-surviving male passengers in each class.
# Out:
# pclass
# 1     77
# 2     91
# 3    300
# Name: survived, dtype: int64

# %%
data[
   ( data['sex']=='male') & (data['survived']==1)].groupby('pclass')['survived'].count()
# Count the number of surviving male passengers in each class.
# Out:
# pclass
# 1    45
# 2    17
# 3    47
# Name: survived, dtype: int64

# %%
sns.heatmap(data.isnull() )
# Generate a heatmap to visualize missing (null) values in the DataFrame.
# Out:
# <Axes: >

# %%
sns.heatmap(data.isnull(), cmap='magma' )
# Generate a heatmap with a 'magma' colormap to visualize missing (null) values.
# Out:
# <Axes: >
